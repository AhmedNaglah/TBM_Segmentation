# %%
import cv2
import tiffslide as openslide
import numpy as np

import logging 

class Slide:
    def __init__(self, config, svsName) -> None:
        self.config = config
        self.svsName = svsName
        self.svsPath = f"{self.config['svsBase']}/{self.svsName}"
        self.s = openslide.open_slide(self.svsPath)

    def smoothBinary(self, mask):
        kn = 2
        iterat = 2
        kernel = np.ones((kn, kn), np.uint8) 
        for _ in range(iterat):
            mask = cv2.erode(mask, kernel, iterations=1) 
            mask = cv2.dilate(mask, kernel, iterations=1) 
        return mask

    def extractForeground(self):
        location = (0,0)
        level = self.s.level_count-1
        size = self.s.level_dimensions[self.s.level_count-1]
        lr = np.array(self.s.read_region(location, level, size))[:,:,:3]

        lrGray = cv2.cvtColor(lr, cv2.COLOR_RGB2GRAY)

        _, thre = cv2.threshold(lrGray, 220, 255, cv2.THRESH_BINARY) # THreshold for White
        threTissue = 255-thre

        self.threTissueSmooth = self.smoothBinary(threTissue)

        thresholdArea = 0.7
        contours, _ = cv2.findContours(self.threTissueSmooth, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        c_max = max(contours, key = cv2.contourArea)
        area_min = cv2.contourArea(c_max) * thresholdArea

        contours_filtered = []

        for contour in contours:
            area = cv2.contourArea(contour)
            if area > area_min:
                contours_filtered.append(cv2.convexHull(contour, returnPoints=True))

        im_ = lrGray*0

        cv2.drawContours(im_, contours_filtered, -1, 255, -1)

        self.threTissueSmooth = np.copy(im_)
                
        return self.threTissueSmooth

    def extractPatches(self, patchSize):
        (w, h) = self.s.level_dimensions[0]
        wn = w//patchSize
        hn = h//patchSize
        self.threTissueSmoothResized = cv2.resize(self.threTissueSmooth, (wn, hn)) # Resize Binary Mask to align with Patches

        self.patches = {}

        for ix in range(wn):
            for iy in range(hn):
                if self.threTissueSmoothResized[iy, ix]==255:
                    try:
                        x = ix*patchSize
                        y = iy*patchSize
                        size = (patchSize, patchSize)
                        level = 0
                        location = (x,y)
                        self.patches[f'{x}_{y}'] = cv2.cvtColor(np.array(self.s.read_region(location, level, size))[:,:,:3], cv2.COLOR_RGB2BGR)
                    except:
                        logging.warning("Exception inside patch extraction")
        
        return self.patches

slideName = 'S-1909-007242_PAS_2of2.svs'
patchSize = 512

config = {
    'svsBase': '/blue/pinaki.sarder/nlucarelli/kpmp_new',
    'patchSize': 512
}

slide = Slide(config, slideName)

w, h = slide.s.level_dimensions[0]

fg = slide.extractForeground()

slide.extractPatches(patchSize)

print((w, h))

print(len(slide.patches))

import matplotlib.pyplot as plt

# %matplotlib inline

keys = list(slide.patches)

fig = plt.figure(figsize = (20,7))

plt.imshow(fg, cmap='gray')
# Out:
# (91677, 34010)
# 928

# %%
im = cv2.cvtColor(slide.patches[keys[101]], cv2.COLOR_BGR2RGB)

plt.imshow(im)

# %%
import tensorflow as tf
import numpy as np
import cv2
from models.cycleGAN512 import cycleGAN512

def GANInference(im, checkpoint_path): # Takes BGR image and Return BGR

    cycleGAN = cycleGAN512()
    cycleGAN.built = True
    cycleGAN.load_weights(checkpoint_path)

    def normalize(input_image):
        input_image = (input_image / 127.5) - 1

        return input_image

    def TF2CV(im):
        img = tf.cast(tf.math.scalar_mul(255/2, im[0]+1), dtype=tf.uint8)
        img_ = np.array(tf.keras.utils.array_to_img(img),dtype='uint8')
        #img_ = cv2.cvtColor(img_, cv2.COLOR_RGB2BGR)
        return img_

    # Model is always trained on RGB internally but expect BGR
    im_ = normalize(im)
    he_ = np.expand_dims(im_, axis=0)

    mt_virtual = cycleGAN(he_)
    mt_virtual_ = TF2CV(mt_virtual)

    return mt_virtual_

# %%
checkpoint_path = "/orange/pinaki.sarder/ahmed.naglah/data/kpmpCycleGAN/output_kpmpCycleGAN2/training_checkpoints/ckpt-9"

# im in RGB for matplotlib ready
imGAN = GANInference(cv2.cvtColor(im, cv2.COLOR_RGB2BGR), checkpoint_path)

concat = cv2.hconcat((im, cv2.cvtColor(imGAN, cv2.COLOR_BGR2RGB)))

fig = plt.figure(figsize = (10,5))

plt.imshow(concat)
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).save_counter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._iterations
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._iterations
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._iterations
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._iterations
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_a_optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator_b_optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.31
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.32
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.33
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.34
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.35
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.36
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.37
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.38
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.39
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.40
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.41
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.42
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.43
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.44
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.45
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.46
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.47
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.48
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.49
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.50
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.51
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.52
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.53
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.54
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.55
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.56
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.57
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.58
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.59
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.60
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.61
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.62
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.63
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.64
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.65
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.66
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.67
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.68
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.69
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.70
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.71
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.72
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.73
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.74
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.75
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.76
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.77
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.78
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.79
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.80
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.81
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.82
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.83
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.84
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.85
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.86
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.87
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.88
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.89
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.90
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.91
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.92
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.93
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.94
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.95
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.96
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.97
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.98
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.99
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.100
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.101
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_g_optimizer._variables.102
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.31
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.32
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.33
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.34
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.35
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.36
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.37
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.38
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.39
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.40
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.41
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.42
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.43
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.44
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.45
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.46
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.47
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.48
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.49
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.50
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.51
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.52
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.53
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.54
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.55
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.56
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.57
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.58
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.59
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.60
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.61
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.62
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.63
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.64
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.65
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.66
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.67
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.68
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.69
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.70
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.71
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.72
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.73
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.74
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.75
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.76
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.77
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.78
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.79
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.80
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.81
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.82
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.83
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.84
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.85
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.86
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.87
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.88
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.89
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.90
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.91
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.92
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.93
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.94
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.95
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.96
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.97
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.98
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.99
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.100
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.101
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator_r_optimizer._variables.102

# %%
import histomicstk as htk

def applyThresholdEosin(patch):
    lower = 170
    upper = 255
    mask = cv2.inRange(patch, lower, upper)
    
    return np.array(255-mask, dtype='uint8') 


def smoothBinary(mask):
    kn = 2
    iterat = 3
    kernel = np.ones((kn, kn), np.uint8) 
    for _ in range(iterat):
        mask = cv2.erode(mask, kernel, iterations=1) 
        mask = cv2.dilate(mask, kernel, iterations=1) 
    return mask

def stainDeconv(im):
    stain_color_map = htk.preprocessing.color_deconvolution.stain_color_map
    #print('stain_color_map:', stain_color_map, sep='\n')

    # specify stains of input image
    stains = ['hematoxylin',  # nuclei stain
                'eosin',        # cytoplasm stain
                'null']         # set to null if input contains only two stains

    # create stain matrix
    W = np.array([stain_color_map[st] for st in stains]).T

    # perform standard color deconvolution
    imDeconvolved = htk.preprocessing.color_deconvolution.color_deconvolution(im, W)

    ## Thresholding
    eosinStain = imDeconvolved.Stains[:, :, 1]

    return eosinStain


thresholdArea = 0.01

xp = [0, 64, 128, 192, 255]
fp = [0, 16, 128, 240, 255]
x = np.arange(256)
table = np.interp(x, xp, fp).astype('uint8')


eosin = stainDeconv(im)

#eosinEqu = cv2.equalizeHist(eosin)

eosinEqu = cv2.LUT(eosin, table)

#imgYuv = cv2.cvtColor(eosin, cv2.COLOR_BGR2YUV)
#imgYuv[:,:,0] = cv2.equalizeHist(imgYuv[:,:,0])
#imEquBGR = cv2.cvtColor(imgYuv, cv2.COLOR_YUV2BGR)

mask = applyThresholdEosin(eosinEqu)
maskSmooth = smoothBinary(mask)
mask3d = cv2.cvtColor(maskSmooth, cv2.COLOR_GRAY2RGB)
eosin3 = cv2.cvtColor(eosin, cv2.COLOR_GRAY2RGB)
eosin3Equ = cv2.cvtColor(eosinEqu, cv2.COLOR_GRAY2RGB)

#contours, _ = cv2.findContours(maskSmooth, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
contours, _ = cv2.findContours(maskSmooth, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

c_max = max(contours, key = cv2.contourArea)
area_min = cv2.contourArea(c_max) * thresholdArea

contours_filtered = []

for contour in contours:
    area = cv2.contourArea(contour)
    if area > area_min:
        contours_filtered.append(contour)

im_ = im*0

cv2.drawContours(im_, contours_filtered, -1, (255, 255, 255), -1)

#imEquBGR = cv2.cvtColor(imEquBGR, cv2.COLOR_BGR2RGB)
concat = cv2.hconcat((im, eosin3, eosin3Equ, mask3d, im_))

fig = plt.figure(figsize = (25,5))

plt.imshow(concat)

# %%
im_ = im*0

cv2.drawContours(im_, contours_filtered, -1, (123, 255, 23), 1)

concat = cv2.hconcat((im, mask3d, im_))

fig = plt.figure(figsize = (15,5))

plt.imshow(concat)
